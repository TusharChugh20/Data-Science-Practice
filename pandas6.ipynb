# %%
import pandas as pd

# %%
dataset=pd.read_csv("fifa_countries_audience.csv")

# %%
dataset.head()
# Out:
#          country confederation  population_share  tv_audience_share  \
# 0  United States      CONCACAF               4.5                4.3
# 1          Japan           AFC               1.9                4.9
# 2          China           AFC              19.5               14.8
# 3        Germany          UEFA               1.2                2.9
# 4         Brazil      CONMEBOL               2.8                7.1
#
#    gdp_weighted_share
# 0                11.3
# 1                 9.1
# 2                 7.3
# 3                 6.3
# 4                 5.4

# %%
#renaming column value
dataset.rename(columns={'tv_audience_share': 'audience_share'})
# Out:
#            country confederation  population_share  audience_share  \
# 0    United States      CONCACAF               4.5             4.3
# 1            Japan           AFC               1.9             4.9
# 2            China           AFC              19.5            14.8
# 3          Germany          UEFA               1.2             2.9
# 4           Brazil      CONMEBOL               2.8             7.1
# ..             ...           ...               ...             ...
# 186          Tonga           OFC               0.0             0.0
# 187        Liberia           CAF               0.1             0.0
# 188          Palau           OFC               0.0             0.0
# 189          Nauru           OFC               0.0             0.0
# 190           Niue           OFC               0.0             0.0
#
#      gdp_weighted_share
# 0                  11.3
# 1                   9.1
# 2                   7.3
# 3                   6.3
# 4                   5.4
# ...

# %%
#renaming row index
dataset.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                    country confederation  population_share  tv_audience_share  \
# firstEntry   United States      CONCACAF               4.5                4.3
# secondEntry          Japan           AFC               1.9                4.9
# 2                    China           AFC              19.5               14.8
# 3                  Germany          UEFA               1.2                2.9
# 4                   Brazil      CONMEBOL               2.8                7.1
# ...                    ...           ...               ...                ...
# 186                  Tonga           OFC               0.0                0.0
# 187                Liberia           CAF               0.1                0.0
# 188                  Palau           OFC               0.0                0.0
# 189                  Nauru           OFC               0.0                0.0
# 190                   Niue           OFC               0.0                0.0
#
#              gdp_weighted_share
# ...

# %%
#renaming or setting axis value
dataset.rename_axis("fields", axis='columns')
# Out:
# fields        country confederation  population_share  tv_audience_share  \
# 0       United States      CONCACAF               4.5                4.3
# 1               Japan           AFC               1.9                4.9
# 2               China           AFC              19.5               14.8
# 3             Germany          UEFA               1.2                2.9
# 4              Brazil      CONMEBOL               2.8                7.1
# ..                ...           ...               ...                ...
# 186             Tonga           OFC               0.0                0.0
# 187           Liberia           CAF               0.1                0.0
# 188             Palau           OFC               0.0                0.0
# 189             Nauru           OFC               0.0                0.0
# 190              Niue           OFC               0.0                0.0
#
# fields  gdp_weighted_share
# 0                     11.3
# 1                      9.1
# ...

# %%
dataset1=pd.read_csv("fifa_countries_audience.csv")#191 rows
dataset2=pd.read_csv("olympics.csv")#11 rows

# %%
# concat is used when we have same fieds(column names) in dataset
pd.concat([dataset1, dataset2])
# Out:
#           country confederation  population_share  tv_audience_share  \
# 0   United States      CONCACAF               4.5                4.3
# 1           Japan           AFC               1.9                4.9
# 2           China           AFC              19.5               14.8
# 3         Germany          UEFA               1.2                2.9
# 4          Brazil      CONMEBOL               2.8                7.1
# ..            ...           ...               ...                ...
# 6           Italy          UEFA               0.9                2.1
# 7          France          UEFA               0.9                2.0
# 8          Russia          UEFA               2.1                3.1
# 9           Spain          UEFA               0.7                1.8
# 10    South Korea           AFC               0.7                1.8
#
#     gdp_weighted_share
# 0                 11.3
# 1                  9.1
# 2                  7.3
# 3                  6.3
# ...

# %%
# join() lets you combine different DataFrame objects which have an index in common.
dataset1=pd.read_csv("fifa_countries_audience.csv")#191rows
dataset2=pd.read_csv("olympics.csv")#11rows
dataset1.join(dataset2 ,lsuffix='country', rsuffix='country')
# Out:
#     countrycountry confederationcountry  population_sharecountry  \
# 0    United States             CONCACAF                      4.5
# 1            Japan                  AFC                      1.9
# 2            China                  AFC                     19.5
# 3          Germany                 UEFA                      1.2
# 4           Brazil             CONMEBOL                      2.8
# ..             ...                  ...                      ...
# 186          Tonga                  OFC                      0.0
# 187        Liberia                  CAF                      0.1
# 188          Palau                  OFC                      0.0
# 189          Nauru                  OFC                      0.0
# 190           Niue                  OFC                      0.0
#
#      tv_audience_sharecountry  gdp_weighted_sharecountry countrycountry  \
# 0                         4.3                       11.3  United States
# ...
